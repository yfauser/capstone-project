# %%
# %matplotlib inline

# %%
import scaleogram as scg

# %%
axes = scg.plot_wav('cmor1-1.5', figsize=(14,3))

# %%
axes = scg.plot_wav('cmor1-3', figsize=(14,3))

# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt

# %%
from scipy.signal import chirp

# %%
# Define signal
fs = 128.0
sampling_period = 1 / fs
t = np.linspace(0, 2, 2 * fs)
x = chirp(t, 10, 2, 40, 'quadratic')

# Calculate continuous wavelet transform
coef, freqs = pywt.cwt(x, np.arange(1, 50), 'morl',
                       sampling_period=sampling_period)

# Show w.r.t. time and frequency
plt.figure(figsize=(20, 10))
plt.pcolor(t, freqs, coef)

# Set yscale, ylim and labels
plt.yscale('log')
plt.ylim([1, 100])
plt.ylabel('Frequency (Hz)')
plt.xlabel('Time (sec)')
plt.show()
# Out:
# /anaconda3/envs/py3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.
